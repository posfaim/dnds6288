# %% [markdown]
# # Scientific Python
# ## Central European University
#
# ## 03 Numpy, matplotlib, datetime -- Exercises
#
# Instructor: Márton Pósfai
#
# Email: posfaim@ceu.edu

# %% [markdown]
# *Don't forget:* use the Slack channel for discussion, to ask questions, or to show solutions to exercises that are different from the ones provided in the notebook. [Slack channel](http://www.personal.ceu.edu/staff/Marton_Posfai/slack_forward.html)

# %% [markdown]
# ## Final problem of class 02
#
# The following dictionaries `Dweight` and `Dheight` contain the weight in kilograms and height in meters of a collection of people.
# * Write code that creates a list of names that is sorted based body mass index (weight/height^2).
# * Then print out the names of whom are considered to be in "obesity class III" [according to WHO](https://www.euro.who.int/en/health-topics/disease-prevention/nutrition/a-healthy-lifestyle/body-mass-index-bmi) (BMI>40).

# %%
Dweight = {"Bob": 70, "Jaba the Hutt": 1358,  "Mata Hari": 65, 
           "Genghis Khan": 75,"Alice": 60,  "Papa Smurf": .2}
Dheight = {"Alice": 1.7, "Mata Hari": 1.65, "Bob": 1.80, 
           "Genghis Khan": 1.65,"Jaba the Hutt": 1.75, "Papa Smurf": .07}

# %% [markdown]
# Note that the keys are not in the same order, so the following does not work:

# %%
bmis = []
for w,h in zip(Dweight.values(),Dheight.values()):
    bmis.append(w/h**2)
bmis

# %% [markdown]
# Common approach:

# %%
bmis = []
for name in Dweight.keys():
    bmis.append((name, Dweight[name]/Dheight[name]**2))
bmis

# %%
bmis.sort(key = lambda t: t[1])
bmis

# %%
[t[0] for t in bmis]

# %%
[name for name,bmi in bmis if bmi>40]

# %% [markdown]
# A concise solution

# %%
sorted_names = sorted(Dweight.keys(), 
                      key=lambda name: Dweight[name]/Dheight[name]**2)
print(sorted_names)

obesity_classIII = [name for name in Dweight.keys() 
                    if Dweight[name]/Dheight[name]**2>40 ]
print(obesity_classIII)

# %% [markdown]
# ## Exercises

# %% [markdown]
# Importing the modules that we need:

# %%
import numpy as np
import timeit
import math
import itertools
import matplotlib.pyplot as plt

# %% [markdown]
# ### 01 Creating arrays, copies and views
#
# Create an array `a` containing the integers from 0 to 7:
# * Create a one dimensional view `b` that only contains the first four elements of `a`
# * Create an array `c` that is an independent copy of the last four elements of `a`
# * Create a view `d` that contains every second element of `a`
#
# <details><summary><u>Hint.</u></summary>
# <p>
#
# Slicing creates a new view of an array, to make a copy of an array `A` use `A.copy()`. If you are uncertain whether you created a copy of a view, test your code!
#
# </p>
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# a = np.arange(8)
# d = a[::2]
# b = a[:4]
# c = a[4:].copy()
#
# #test
# b[0]=-1
# c[0]=-1
# d[0]=100
# a,b,c,d
#
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 02 2D slicing
#
# Convert the following list of lists to a two dimensional array of floats `a` and print out
# * `a`,
# * its first column,
# * its upper left 2x2 submatrix,
# * and its upper right 2x2 submatrix using slicing.
#
# <details><summary><u>Hint.</u></summary>
# <p>
#
# If you are slicing two dimensional arrays use the indexing style `a[i,j]` where `i` is the row and `j` is the column. For example, `a[0:2,0:2]` is not equivalent to `a[0:2][0:2]`
#
# Remember the empty slice `:` returns the entire range, for example,  `a[0,:]` is the first row of `a`.
#
# </p>
# </details>

# %%
l = [[8,9,7],[3,4,42],[1,2,3]]

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
#
# a = np.array(l,dtype=np.double)
# print('a:', a)
# print('first column:', a[:,0])
# print('upper left:', a[0:2,0:2])
# print('upper right:',a[0:2,1:3])
# #or
# print('upper right:',a[0:2,-2:])
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 03 Numpy array operations
#
# Calculate the sum of the first 100 square numbers, i.e., $1+2^2+3^2+\ldots 100^2$. Vectorize your code, i.e., do not use a `for` loop!
#
# <details><summary><u>Hint.</u></summary>
# <p>
#
# Simple array operations get applied elementwise, for example if we add togethre two arrays as`c=a+b`, `c[i]` will be equal to `a[i]+b[i]` for all `i`s.
#
# To sum up all elements of an array `a` use the method `a.sum()`.
#
# </p>
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# a=np.arange(1,101)
# (a*a).sum()
#
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 04 Numpy array operations
# * Using numpy array operations and without `for` loops, write a function that computes the same value as the function `f(n)`.
# * Compare the runtime of the two implementations as a function of `n`.
#
# <details><summary><u>Hint.</u></summary>
# <p>
#
# You can measure runtime of a function `f()` with the `timeit.timeit(f)` function. To pass an argument is to use a lambda function as `timeit.timeit(lambda :f(n))`.
#
# </p>
# </details>

# %%
def f(n):
    x = 0
    for i in range(n):
            x+=math.cos(i)    
    return x

# %% [markdown]
# <details><summary><u>Solution part 1.</u></summary>
# <p>
#
# ```python
# def np_f(n):
#     a = np.arange(n)
#     x = np.sum(np.cos(a))
#
#     return x
#
# print(f(10))
# print(np_f(10))
# ```
#
# </p>
# </details>
#
# <details><summary><u>Solution part 2.</u></summary>
# <p>
#
# ```python
# ns  = np.arange(10,10000,500)
# rts = [timeit.timeit(lambda :f(n),number=10) for n in ns]
# np_rts =[timeit.timeit(lambda :np_f(n),number=10) for n in ns]
#
# plt.plot(ns,rts, label='for loop')
# plt.plot(ns,np_rts,label='numpy')
# plt.xlabel('n')
# plt.ylabel('runtime')
# plt.legend()
#
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 05 Numpy operations -- Discussion exercise
#
# You have a collection of boxes, and you store their dimensions in a numpy array such that each box is a row and the first column is the height, the second is the width, and the third is the length of each box.
# * Calculate the total volume of the boxes.
# * Generate an array of 1000 boxes with random sizes uniformly distributed between 1 and 3. Calculate their average volume.

# %%
boxes = np.array([[2,2,2],[3.5,3,12],[2,3,0.5],[1,1.5,1]])

# %% [markdown]
# **Share your solution on Slack. We will discuss the problem during class together.**

# %% [markdown]
# ### 06 Masking
#
# The array `w` contains the weight of a list of vehicles and the array `o` contains their maximum occupancy.
# * What is the minimum weight of a vehicle that can seat at least 7 people?
# * What is the average occupancy of vehicles below one tonne (1000 kg)?
#
# <details><summary><u>Hint.</u></summary>
# <p>
#
# A mask is an array of `True` or `False` values, `a[mask]` provides all elements of `a` where `mask` is `True`.
#
# You can create a mask easily using elementwise comparison, for example, `a>0` provides a mask that is `True` whereever `a` is positive.
#
# </p>
# </details>

# %%
w = np.array([110.,980.,4510.,2540.,550.,1330.,1850.])
o = np.array([1,     4,   10,    8,   2,    6,    7.])

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# print(w[o>=7].min())
# print(o[w<1000].mean())
#
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 07 Line plot
#
# Using a for loop create a figure that plots $\sin(x)$, $\sin(2x)$ and $\sin(3x)$ for $x$ between 0 and $2\pi$. Set the color of the lines black, but change the linestyle (solid, dashed, dotted). Label the axes and create a legend too!
#
# Change the labels at along the x axis so that they say $0$, $\pi$ and $2\pi$. You can use latex expressions in matplotlib labels, e.g. the string `r"$\pi$"` renders as a nice looking $\pi$.
#
# <details><summary><u>Hint</u></summary>
# <p>
#
# The format strings `'k-'`, `'k--'` and `'k:'` generate solid, dashed and dotted black lines, respectively.
#
# You can change the labels on the x axis using the `plt.xtics()` function.
#
# </p>
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# xs = np.linspace(0,2*np.pi,100)
# for k, ls in zip([1,2,3],['-','--',':']):
#     plt.plot(xs,np.sin(k*xs),ls+'k',label=r"$\sin(%dx)$"%k)
# plt.legend()
#
# plt.xticks(ticks=[0,np.pi,2*np.pi],labels=["0",r"$\pi$",r"$2\pi$"])
#
# plt.xlabel('x')
# plt.ylabel('y')
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 08 Subplots
#
# You can change an axis to log-scale using the `plt.xscale('log')` or `plt.yscale('log')` functions. Create a 2x2 array of subplots, each subplot should show the same three functions: $x^2$, $-\log(x)$ and $\exp(x)$.
#
# Add a legend to at least one of the subplots.
#
# <details><summary><u>Hint</u></summary>
# <p>
#
# To set the scale of the x axis to logarithmic use `plt.xscale('log')`, to set it to linear scale use `plt.xscale('linear')`.
#
# You can use `for` loops to iterate over the axes in the figure, but sometimes you might decide that it is more straight forward to just create each subplot separately.
#
# To make the figure more legible, you can change the figure size when you create the subplots:
# ```python
#     fig, axs = plt.subplots(2,2,figsize=(10,6))
# ```
#
# </p>
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# fig, axs = plt.subplots(2,2,figsize=(10,6))
#
# xs = np.linspace(.1,1,100)
#
# for i,sx in zip([0,1],['linear','log']):
#     for j,sy in zip([0,1],['linear','log']):
#         plt.sca(axs[i][j])
#         plt.plot(xs,np.exp(xs),label=r'$\exp(x)$')
#         plt.plot(xs, -np.log(xs),label=r'$-\log(x)$')
#         plt.plot(xs,2*xs**2,label=r'$2x^2$')
#
#         plt.xscale(sx)
#         plt.yscale(sy)
#
#         plt.xlabel('x')
#         plt.ylabel('y')
#
# plt.legend()
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 09 Histogram
#
# Measure the runtime of the function provided below a 2000 times. Plot the histogram of the values, draw a verticle line for the mean runtime and for the minimum observed runtime.
#
# Try choosing the number of bins so that you can see the shape of the distribution. Try changing the y axis to logarithmic scale.
#
# <details><summary><u>Hint</u></summary>
# <p>
#
# You can collect the runtimes using the `timeit.repeat()` function:
# ```python
#     rts = timeit.repeat(f,number=1,repeat=2000)
# ```
#
# To draw a vertical line use `plt.axvline()`.
#
# </p>
# </details>

# %%
def f():
    for i in range(1000):
        np.cos(i)+np.sin(i)
    return

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# rts = timeit.repeat(f,number=1,repeat=2000)
#
# plt.hist(rts,bins=100);
# plt.yscale('log')
# plt.axvline(np.mean(rts),color='r',label='mean')
# plt.axvline(min(rts),color='k',label='min')
# plt.xlabel('runtime')
# plt.ylabel('count')
# plt.legend()
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 10 Letter frequency
#
# Write a function that takes a file name as input and returns a dictionary that has the lower case standard English characters as keys (as they are provided in the `abc` string) and the values correspond to the number of times they appear in the file. (This may remind you of an exercise from previous class.)
#
# Find and download a text file online that contains some text, for example you can get Moby Dick in several languages from [here](https://linguabooster.com/en/en/book/moby-dick-or-the-whale). Make a bar plot such that each bar corresponds to a letter and the height to the number times they appear in the file. Change the xtic labels to show letters instead of numbers.
#
# <details><summary><u>Hint</u></summary>
# <p>
#
# You can read the entire contents of a file with
# ```python
#     with open(filename) as f:
#         contents = f.read()
# ```
# And you can count the number of occurances of a character `c` using `contents.count(c)`.
#
# </p>
# </details>

# %%
abc = 'abcdefghijklmnopqrstuvwxyz'

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# def lettercount(filename):
#     with open(filename) as f:
#         contents = f.read()
#
#     Dlettcount = {c:contents.count(c) for c in abc}
#
#     return Dlettcount
#
# Dlc = lettercount("moby_dick-english.txt")
#
#
# fig,ax = plt.subplots()
# plt.bar(np.arange(len(abc)),[Dlc[c] for c in abc])
# plt.ylabel("Number of occurences")
# plt.xticks(ticks=np.arange(len(abc)),labels=[c for c in abc]);
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 11 Comparing texts
#
# Download two text files from the internet and make a scatter plot that compares the frequency that lower case standard English characters appear in them. Reuse your code -- use the function that you wrote for the previous exercise. Normalize the letter count such that they sum to 1. The x axes of the scatter plot should be the first file and the y axis the second file.
#
# For more fun, add a line with slope 1 corresponding to perfect correlation.
#
# You can also try to annotate each point with the letter that they correspond to with the `plt.annotate()` function.
#
# Try comparing different languages or code to standard text!
#
# <details><summary><u>Hint</u></summary>
# <p>
#
# To calculate a list containing the letter frequencies based letter counts
# ```python
#     all_lett_count = sum(Dlc.values())
#     lf  = [Dlc[c]/all_lett_count for c in abc]
# ```
# where `Dlc` is the dictionary returned by the function you wrote for the previous exercise.
#
# </p>
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# file1 = "moby_dick-english.txt"
# file2 = "moby_dick-german.txt"
# Dlc1 = lettercount(file1)
# Dlc2 = lettercount(file2)
#
# all_lett_count = sum(Dlc1.values())
# lf1  = [Dlc1[c]/all_lett_count for c in abc]
#
# all_lett_count = sum(Dlc2.values())
# lf2  = [Dlc2[c]/all_lett_count for c in abc]
#
# plt.plot([min(lf1),max(lf1)],[min(lf1),max(lf1)],'k--',linewidth=.5)
# plt.scatter(lf1,lf2)
# plt.xlabel(file1)
# plt.ylabel(file2)
# plt.title('Comparing letter frequencies')
#
# #for x,y,c in zip(lf1,lf2,abc):
# #    plt.annotate(c, (x,y),fontsize=12)
# ```
#
# </p>
# </details>

# %% [markdown]
# ### 12 Days since Waterloo
#
# Create a text file with name containing today's date in format YYYYMMDD, the file should contain a number equal to the number of days since Napoleon's defeat at Waterloo.
#
# <details><summary><u>Hint</u></summary>
# <p>
#
# The get the number of days between two dates use
# ```python
#     (Dnow-Dwaterloo).days
# ```
#
# </p>
# </details>

# %% [markdown]
# <details><summary><u>Solution.</u></summary>
# <p>
#
# ```python
# Dnow = datetime.datetime.now()
# Dwaterloo = datetime.datetime(1815, 6, 18)
#
# filename = "Waterloo"+Dwaterloo.strftime("%Y%m%d")+".txt"
# with open(filename,'w') as f:
#     f.write(str((Dnow-Dwaterloo).days))
# ```
#
# </p>
# </details>

# %% [markdown]
# ## Final problem
#
# Solve the following problem and copy your solution into the moodle assignment.
#
# ### Part I: Normal distribution without `np.random.normal`
#
# According to the [central limit theorem](https://en.wikipedia.org/wiki/Central_limit_theorem), the appropriately rescaled sum of identically distributed random variables converges to the standard normal distribution if the random variables have finite variance. More precisely, if $X_1,X_2,\ldots,X_n$ are iid random variables with mean $\mu$ and variance $\sigma^2$, their rescaled sum
# $$Z_n = \frac{\sum_{i=1}^{n}(X_i - \mu)}{\sigma\sqrt{n}}$$
# converges to the standard normal distribution as $n\rightarrow\infty$. This allows us to (very inefficiently) generate approximately normally distributed random numbers.
#
#
# Your task is to generate an array `clt_rand` that contains $10,000$ normally distributed random numbers using the central limit theorem by
# 1. Generating $n=1,000$ uniform random numbers betwenn 0 and 1 using `np.random.random`
# 2. Calculating their rescaled sum, i.e.,
#     * subtract the theoretical mean from each random value (the mean of the [standard unform distibution](https://en.wikipedia.org/wiki/Continuous_uniform_distribution) is $1/2$),
#     * calculate their sum,
#     * and divide this by the theoretical standard deviation and $\sqrt{n}$ (the standard deviation is $1/\sqrt{12}$).
# 3. Repeating this $10,000$ times.
#
# **Grading: To get full points do not use explicit Python loops.**

# %% [markdown]
# ### Part II: Plot the histogram
#
# Create matplotlib histogram of the random numbers in the array `clt_rand` and compare it to the theoretical normal probability density function.

# %% [markdown]
# ## Extra credit problem
#
# Consider the following array of a million uniform random floats:

# %% [raw]
# np.random.seed(42)
# ra = np.random.random(1000000)

# %% [markdown]
# Use this array and numpy operations to approximate $\pi$. Use numpy operations (e.g., no explicit `for` loops allowed).
#
# You get the extra credit if you get the first three digits right, i.e.,`3.14`.
#
# If you figured $\pi$ out, you can try the harder problem of estimating Euler's constant $e$ (without the use of the exponential function) for additional extra credit.
